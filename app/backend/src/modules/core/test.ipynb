# %%
from entity_dxf import EntityDxf

file = EntityDxf('teste.dxf')

# %%
for i in file.psp:
    # Verifica o tipo da entidade para saber se ela pode ter texto
    tipo = i.dxftype()
    
    if tipo == 'TEXT':
        # Texto de linha única usa o atributo .dxf.text
        conteudo = i.dxf.text
        print(f"TEXTO: {conteudo}")
        
    elif tipo == 'MTEXT':
        # MText (Multi-line) também usa .dxf.text, mas pode conter
        # códigos de formatação (ex: \P para nova linha)
        conteudo = i.dxf.text
        print(f"MTEXTO: {conteudo}")
        
    elif tipo == 'ATTRIB' or tipo == 'ATTDEF':
        # Se forem atributos de blocos (como em carimbos/selos)
        conteudo = i.dxf.text
        print(f"ATRIBUTO: {conteudo}")
# Out:
# MTEXTO: \pxt13;{\fArial|b1|i0|c0|p34;Responsável:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Cliente:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Empreendimento:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Data:}
# MTEXTO: {\fArial|b1|i0|c0|p34;15/07/25}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Revisão:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Rev. 0}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Escala:}
# MTEXTO: {\fArial|b1|i0|c0|p34;Indicada}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Desenho nº:}
# MTEXTO: {\fArial|b1|i0|c0|p34;1/3}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Prancha nº:}
# MTEXTO: {\fArial|b1|i0|c0|p34;2/6}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Título:}
# MTEXTO: {\fArial Black|b1|i0|c0|p34;Planta de Arquitetura a demolir }
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;CH SEC PRJ INFRAESTRUTURA}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Eng. Resp.:}
# MTEXTO: {\fArial Black|b1|i0|c0|p34;Vila Frei Galvão - Comando da Brigada Aeromóvel}
# MTEXTO: {\fArial|b1|i0|c0|p34;Adequação de Instalações}
# MTEXTO: {\fArial|b1|i0|c0|p34;Comando da Brigada Aeromóvel}
# MTEXTO: {\fArial|b1|i0|c0|p34;Eng. José  Henrique de Cássio Ruffo - CREA:5061382840-SP}
# MTEXTO: \pxt13;{\fArial|b1|i0|c0|p34;Responsável:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Cliente:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Empreendimento:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Data:}
# MTEXTO: {\fArial|b1|i0|c0|p34;15/07/25}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Revisão:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Rev. 0}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Escala:}
# MTEXTO: {\fArial|b1|i0|c0|p34;Indicada}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Desenho nº:}
# MTEXTO: {\fArial|b1|i0|c0|p34;2/3}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Prancha nº:}
# MTEXTO: {\fArial|b1|i0|c0|p34;2/6}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Título:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;CH SEC PRJ INFRAESTRUTURA}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Eng. Resp.:}
# MTEXTO: {\fArial Black|b1|i0|c0|p34;Vila Frei Galvão - Comando da Brigada Aeromóvel}
# MTEXTO: {\fArial|b1|i0|c0|p34;Adequação de Instalações}
# MTEXTO: {\fArial|b1|i0|c0|p34;Comando da Brigada Aeromóvel}
# MTEXTO: {\fArial|b1|i0|c0|p34;Eng. José  Henrique de Cássio Ruffo - CREA:5061382840-SP}
# MTEXTO: \pxt13;{\fArial|b1|i0|c0|p34;Responsável:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Cliente:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Empreendimento:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Data:}
# MTEXTO: {\fArial|b1|i0|c0|p34;15/07/25}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Revisão:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Rev. 0}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Escala:}
# MTEXTO: {\fArial|b1|i0|c0|p34;Indicada}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Desenho nº:}
# MTEXTO: {\fArial|b1|i0|c0|p34;3/3}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Prancha nº:}
# MTEXTO: {\fArial|b1|i0|c0|p34;2/6}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Título:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;CH SEC PRJ INFRAESTRUTURA}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Eng. Resp.:}
# MTEXTO: {\fArial Black|b1|i0|c0|p34;Vila Frei Galvão - Comando da Brigada Aeromóvel}
# MTEXTO: {\fArial|b1|i0|c0|p34;Adequação de Instalações}
# MTEXTO: {\fArial|b1|i0|c0|p34;Comando da Brigada Aeromóvel}
# MTEXTO: {\fArial|b1|i0|c0|p34;Eng. José  Henrique de Cássio Ruffo - CREA:5061382840-SP}
# MTEXTO: \pxt13;{\fArial|b1|i0|c0|p34;Responsável:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Cliente:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Empreendimento:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Data:}
# MTEXTO: {\fArial|b1|i0|c0|p34;11/08/25}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Revisão:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Rev. 0}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Escala:}
# MTEXTO: {\fArial|b1|i0|c0|p34;Indicada}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Desenho nº:}
# MTEXTO: {\fArial|b1|i0|c0|p34;1/3}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Prancha nº:}
# MTEXTO: {\fArial|b1|i0|c0|p34;1/6}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Título:}
# MTEXTO: {\fArial Black|b1|i0|c0|p34;Planta de Arquitetura}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;CH SEC PRJ INFRAESTRUTURA}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Eng. Resp.:}
# MTEXTO: {\fArial Black|b1|i0|c0|p34;Vila Frei Galvão - Comando da Brigada Aeromóvel}
# MTEXTO: {\fArial|b1|i0|c0|p34;Adequação de Instalações}
# MTEXTO: {\fArial|b1|i0|c0|p34;Local: Rua Soldado José Alves de Abreu, n° 148, 152 }
# MTEXTO: {\fArial|b1|i0|c0|p34;e 184, Jardim Rafael - Caçapava / SP}
# MTEXTO: {\fArial|b1|i0|c0|p34;Eng. Saumo Josino Cardoso Baggini Azevedo - CREA:5070429000/SP}
# MTEXTO: {\fArial|b1|i0|c0|p34;Comando da Brigada Aeromóvel}
# MTEXTO: {\fArial|b1|i0|c0|p34;Eng. José  Henrique de Cássio Ruffo - CREA:5061382840-SP}
# MTEXTO: \pxt13;{\fArial|b1|i0|c0|p34;Responsável:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Cliente:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Empreendimento:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Data:}
# MTEXTO: {\fArial|b1|i0|c0|p34;11/08/25}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Revisão:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Rev. 0}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Escala:}
# MTEXTO: {\fArial|b1|i0|c0|p34;Indicada}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Desenho nº:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Prancha nº:}
# MTEXTO: {\fArial|b1|i0|c0|p34;1/6}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Título:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;CH SEC PRJ INFRAESTRUTURA}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Eng. Resp.:}
# MTEXTO: {\fArial Black|b1|i0|c0|p34;Vila Frei Galvão - Comando da Brigada Aeromóvel}
# MTEXTO: {\fArial|b1|i0|c0|p34;Adequação de Instalações}
# MTEXTO: {\fArial|b1|i0|c0|p34;Local: Rua Soldado José Alves de Abreu, n° 148, 152 }
# MTEXTO: {\fArial|b1|i0|c0|p34;e 184, Jardim Rafael - Caçapava / SP}
# MTEXTO: {\fArial|b1|i0|c0|p34;Eng. Saumo Josino Cardoso Baggini Azevedo - CREA:5070429000/SP}
# MTEXTO: {\fArial|b1|i0|c0|p34;Comando da Brigada Aeromóvel}
# MTEXTO: {\fArial|b1|i0|c0|p34;Eng. José  Henrique de Cássio Ruffo - CREA:5061382840-SP}
# MTEXTO: \pxt13;{\fArial|b1|i0|c0|p34;Responsável:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Cliente:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Empreendimento:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Data:}
# MTEXTO: {\fArial|b1|i0|c0|p34;11/08/25}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Revisão:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Rev. 0}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Escala:}
# MTEXTO: {\fArial|b1|i0|c0|p34;Indicada}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Desenho nº:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Prancha nº:}
# MTEXTO: {\fArial|b1|i0|c0|p34;1/6}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Título:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;CH SEC PRJ INFRAESTRUTURA}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Eng. Resp.:}
# MTEXTO: {\fArial Black|b1|i0|c0|p34;Vila Frei Galvão - Comando da Brigada Aeromóvel}
# MTEXTO: {\fArial|b1|i0|c0|p34;Adequação de Instalações}
# MTEXTO: {\fArial|b1|i0|c0|p34;Local: Rua Soldado José Alves de Abreu, n° 148, 152 }
# MTEXTO: {\fArial|b1|i0|c0|p34;e 184, Jardim Rafael - Caçapava / SP}
# MTEXTO: {\fArial|b1|i0|c0|p34;Eng. Saumo Josino Cardoso Baggini Azevedo - CREA:5070429000/SP}
# MTEXTO: {\fArial|b1|i0|c0|p34;Comando da Brigada Aeromóvel}
# MTEXTO: {\fArial|b1|i0|c0|p34;Eng. José  Henrique de Cássio Ruffo - CREA:5061382840-SP}
# MTEXTO: {\fArial|b1|i0|c0|p34;Local: Rua Soldado José Alves de Abreu, n° 148, 152 }
# MTEXTO: {\fArial|b1|i0|c0|p34;e 184, Jardim Rafael - Caçapava / SP}
# MTEXTO: {\fArial|b1|i0|c0|p34;Eng. Saumo Josino Cardoso Baggini Azevedo - CREA:5070429000/SP}
# MTEXTO: {\fArial|b1|i0|c0|p34;Local: Rua Soldado José Alves de Abreu, n° 148, 152 }
# MTEXTO: {\fArial|b1|i0|c0|p34;e 184, Jardim Rafael - Caçapava / SP}
# MTEXTO: {\fArial|b1|i0|c0|p34;Eng. Saumo Josino Cardoso Baggini Azevedo - CREA:5070429000/SP}
# MTEXTO: {\fArial|b1|i0|c0|p34;Local: Rua Soldado José Alves de Abreu, n° 148, 152 }
# MTEXTO: {\fArial|b1|i0|c0|p34;e 184, Jardim Rafael - Caçapava / SP}
# MTEXTO: {\fArial|b1|i0|c0|p34;Eng. Saumo Josino Cardoso Baggini Azevedo - CREA:5070429000/SP}
# MTEXTO: \pxt13;{\fArial|b1|i0|c0|p34;Responsável:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Cliente:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Empreendimento:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Data:}
# MTEXTO: {\fArial|b1|i0|c0|p34;15/07/25}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Revisão:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Rev. 0}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Escala:}
# MTEXTO: {\fArial|b1|i0|c0|p34;Indicada}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Desenho nº:}
# MTEXTO: {\fArial|b1|i0|c0|p34;1/3}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Prancha nº:}
# MTEXTO: {\fArial|b1|i0|c0|p34;3/6}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Título:}
# MTEXTO: {\fArial Black|b1|i0|c0|p34;Planta de Arquitetura a construir }
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;CH SEC PRJ INFRAESTRUTURA}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Eng. Resp.:}
# MTEXTO: {\fArial Black|b1|i0|c0|p34;Vila Frei Galvão - Comando da Brigada Aeromóvel}
# MTEXTO: {\fArial|b1|i0|c0|p34;Adequação de Instalações}
# MTEXTO: {\fArial|b1|i0|c0|p34;Comando da Brigada Aeromóvel}
# MTEXTO: {\fArial|b1|i0|c0|p34;Eng. José  Henrique de Cássio Ruffo - CREA:5061382840-SP}
# MTEXTO: \pxt13;{\fArial|b1|i0|c0|p34;Responsável:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Cliente:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Empreendimento:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Data:}
# MTEXTO: {\fArial|b1|i0|c0|p34;15/07/25}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Revisão:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Rev. 0}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Escala:}
# MTEXTO: {\fArial|b1|i0|c0|p34;Indicada}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Desenho nº:}
# MTEXTO: {\fArial|b1|i0|c0|p34;2/3}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Prancha nº:}
# MTEXTO: {\fArial|b1|i0|c0|p34;3/6}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Título:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;CH SEC PRJ INFRAESTRUTURA}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Eng. Resp.:}
# MTEXTO: {\fArial Black|b1|i0|c0|p34;Vila Frei Galvão - Comando da Brigada Aeromóvel}
# MTEXTO: {\fArial|b1|i0|c0|p34;Adequação de Instalações}
# MTEXTO: {\fArial|b1|i0|c0|p34;Comando da Brigada Aeromóvel}
# MTEXTO: {\fArial|b1|i0|c0|p34;Eng. José  Henrique de Cássio Ruffo - CREA:5061382840-SP}
# MTEXTO: \pxt13;{\fArial|b1|i0|c0|p34;Responsável:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Cliente:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Empreendimento:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Data:}
# MTEXTO: {\fArial|b1|i0|c0|p34;15/07/25}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Revisão:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Rev. 0}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Escala:}
# MTEXTO: {\fArial|b1|i0|c0|p34;Indicada}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Desenho nº:}
# MTEXTO: {\fArial|b1|i0|c0|p34;3/3}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Prancha nº:}
# MTEXTO: {\fArial|b1|i0|c0|p34;3/6}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Título:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;CH SEC PRJ INFRAESTRUTURA}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Eng. Resp.:}
# MTEXTO: {\fArial Black|b1|i0|c0|p34;Vila Frei Galvão - Comando da Brigada Aeromóvel}
# MTEXTO: {\fArial|b1|i0|c0|p34;Adequação de Instalações}
# MTEXTO: {\fArial|b1|i0|c0|p34;Comando da Brigada Aeromóvel}
# MTEXTO: {\fArial|b1|i0|c0|p34;Eng. José  Henrique de Cássio Ruffo - CREA:5061382840-SP}
# MTEXTO: {\fArial|b1|i0|c0|p34;Local: Rua Soldado José Alves de Abreu, n° 148, 152 }
# MTEXTO: {\fArial|b1|i0|c0|p34;e 184, Jardim Rafael - Caçapava / SP}
# MTEXTO: {\fArial|b1|i0|c0|p34;Eng. Saumo Josino Cardoso Baggini Azevedo - CREA:5070429000/SP}
# MTEXTO: {\fArial|b1|i0|c0|p34;Local: Rua Soldado José Alves de Abreu, n° 148, 152 }
# MTEXTO: {\fArial|b1|i0|c0|p34;e 184, Jardim Rafael - Caçapava / SP}
# MTEXTO: {\fArial|b1|i0|c0|p34;Eng. Saumo Josino Cardoso Baggini Azevedo - CREA:5070429000/SP}
# MTEXTO: {\fArial|b1|i0|c0|p34;Local: Rua Soldado José Alves de Abreu, n° 148, 152 }
# MTEXTO: {\fArial|b1|i0|c0|p34;e 184, Jardim Rafael - Caçapava / SP}
# MTEXTO: {\fArial|b1|i0|c0|p34;Eng. Saumo Josino Cardoso Baggini Azevedo - CREA:5070429000/SP}
# MTEXTO: {\fArial Black|b1|i0|c0|p34;Planta de Arquitetura}
# MTEXTO: {\fArial Black|b1|i0|c0|p34;Planta de Arquitetura}
# MTEXTO: {\fArial Black|b1|i0|c0|p34;Planta de Arquitetura a demolir }
# MTEXTO: {\fArial Black|b1|i0|c0|p34;Planta de Arquitetura a demolir }
# MTEXTO: {\fArial Black|b1|i0|c0|p34;Planta de Arquitetura a construir }
# MTEXTO: {\fArial Black|b1|i0|c0|p34;Planta de Arquitetura a construir }
# MTEXTO: \pxt13;{\fArial|b1|i0|c0|p34;Responsável:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Cliente:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Empreendimento:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Data:}
# MTEXTO: {\fArial|b1|i0|c0|p34;15/07/25}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Revisão:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Rev. 0}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Escala:}
# MTEXTO: {\fArial|b1|i0|c0|p34;Indicada}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Desenho nº:}
# MTEXTO: {\fArial|b1|i0|c0|p34;1/1}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Prancha nº:}
# MTEXTO: {\fArial|b1|i0|c0|p34;4/6}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Título:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;CH SEC PRJ INFRAESTRUTURA}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Eng. Resp.:}
# MTEXTO: {\fArial Black|b1|i0|c0|p34;Vila Frei Galvão - Comando da Brigada Aeromóvel}
# MTEXTO: {\fArial|b1|i0|c0|p34;Adequação de Instalações}
# MTEXTO: {\fArial|b1|i0|c0|p34;Comando da Brigada Aeromóvel}
# MTEXTO: {\fArial|b1|i0|c0|p34;Eng. José  Henrique de Cássio Ruffo - CREA:5061382840-SP}
# MTEXTO: {\fArial|b1|i0|c0|p34;Local: Rua Soldado José Alves de Abreu, n° 148, 152 }
# MTEXTO: {\fArial|b1|i0|c0|p34;e 184, Jardim Rafael - Caçapava / SP}
# MTEXTO: {\fArial|b1|i0|c0|p34;Eng. Saumo Josino Cardoso Baggini Azevedo - CREA:5070429000/SP}
# MTEXTO: {\fArial Black|b1|i0|c0|p34;Planta de Estruturas}
# MTEXTO: \pxt13;{\fArial|b1|i0|c0|p34;Responsável:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Cliente:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Empreendimento:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Data:}
# MTEXTO: {\fArial|b1|i0|c0|p34;15/07/25}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Revisão:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Rev. 0}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Escala:}
# MTEXTO: {\fArial|b1|i0|c0|p34;Indicada}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Desenho nº:}
# MTEXTO: {\fArial|b1|i0|c0|p34;1/4}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Prancha nº:}
# MTEXTO: {\fArial|b1|i0|c0|p34;5/6}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Título:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;CH SEC PRJ INFRAESTRUTURA}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Eng. Resp.:}
# MTEXTO: {\fArial Black|b1|i0|c0|p34;Vila Frei Galvão - Comando da Brigada Aeromóvel}
# MTEXTO: {\fArial|b1|i0|c0|p34;Adequação de Instalações}
# MTEXTO: {\fArial|b1|i0|c0|p34;Comando da Brigada Aeromóvel}
# MTEXTO: {\fArial|b1|i0|c0|p34;Eng. José  Henrique de Cássio Ruffo - CREA:5061382840-SP}
# MTEXTO: {\fArial|b1|i0|c0|p34;Local: Rua Soldado José Alves de Abreu, n° 148, 152 }
# MTEXTO: {\fArial|b1|i0|c0|p34;e 184, Jardim Rafael - Caçapava / SP}
# MTEXTO: {\fArial|b1|i0|c0|p34;Eng. Saumo Josino Cardoso Baggini Azevedo - CREA:5070429000/SP}
# MTEXTO: {\fArial Black|b1|i0|c0|p34;Planta de Instalações Elétricas e Dados}
# MTEXTO: \pxt13;{\fArial|b1|i0|c0|p34;Responsável:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Cliente:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Empreendimento:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Data:}
# MTEXTO: {\fArial|b1|i0|c0|p34;15/07/25}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Revisão:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Rev. 0}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Escala:}
# MTEXTO: {\fArial|b1|i0|c0|p34;Indicada}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Desenho nº:}
# MTEXTO: {\fArial|b1|i0|c0|p34;2/4}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Prancha nº:}
# MTEXTO: {\fArial|b1|i0|c0|p34;5/6}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Título:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;CH SEC PRJ INFRAESTRUTURA}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Eng. Resp.:}
# MTEXTO: {\fArial Black|b1|i0|c0|p34;Vila Frei Galvão - Comando da Brigada Aeromóvel}
# MTEXTO: {\fArial|b1|i0|c0|p34;Adequação de Instalações}
# MTEXTO: {\fArial|b1|i0|c0|p34;Comando da Brigada Aeromóvel}
# MTEXTO: {\fArial|b1|i0|c0|p34;Eng. José  Henrique de Cássio Ruffo - CREA:5061382840-SP}
# MTEXTO: {\fArial|b1|i0|c0|p34;Local: Rua Soldado José Alves de Abreu, n° 148, 152 }
# MTEXTO: {\fArial|b1|i0|c0|p34;e 184, Jardim Rafael - Caçapava / SP}
# MTEXTO: {\fArial|b1|i0|c0|p34;Eng. Saumo Josino Cardoso Baggini Azevedo - CREA:5070429000/SP}
# MTEXTO: \pxt13;{\fArial|b1|i0|c0|p34;Responsável:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Cliente:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Empreendimento:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Data:}
# MTEXTO: {\fArial|b1|i0|c0|p34;15/07/25}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Revisão:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Rev. 0}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Escala:}
# MTEXTO: {\fArial|b1|i0|c0|p34;Indicada}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Desenho nº:}
# MTEXTO: {\fArial|b1|i0|c0|p34;1/1}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Prancha nº:}
# MTEXTO: {\fArial|b1|i0|c0|p34;6/6}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Título:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;CH SEC PRJ INFRAESTRUTURA}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Eng. Resp.:}
# MTEXTO: {\fArial Black|b1|i0|c0|p34;Vila Frei Galvão - Comando da Brigada Aeromóvel}
# MTEXTO: {\fArial|b1|i0|c0|p34;Adequação de Instalações}
# MTEXTO: {\fArial|b1|i0|c0|p34;Comando da Brigada Aeromóvel}
# MTEXTO: {\fArial|b1|i0|c0|p34;Eng. José  Henrique de Cássio Ruffo - CREA:5061382840-SP}
# MTEXTO: {\fArial|b1|i0|c0|p34;Local: Rua Soldado José Alves de Abreu, n° 148, 152 }
# MTEXTO: {\fArial|b1|i0|c0|p34;e 184, Jardim Rafael - Caçapava / SP}
# MTEXTO: {\fArial|b1|i0|c0|p34;Eng. Saumo Josino Cardoso Baggini Azevedo - CREA:5070429000/SP}
# MTEXTO: {\fArial Black|b1|i0|c0|p34;Planta de SPDA}
# MTEXTO: \pxt13;{\fArial|b1|i0|c0|p34;Responsável:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Cliente:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Empreendimento:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Data:}
# MTEXTO: {\fArial|b1|i0|c0|p34;15/07/25}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Revisão:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Rev. 0}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Escala:}
# MTEXTO: {\fArial|b1|i0|c0|p34;Indicada}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Desenho nº:}
# MTEXTO: {\fArial|b1|i0|c0|p34;3/4}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Prancha nº:}
# MTEXTO: {\fArial|b1|i0|c0|p34;5/6}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Título:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;CH SEC PRJ INFRAESTRUTURA}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Eng. Resp.:}
# MTEXTO: {\fArial Black|b1|i0|c0|p34;Vila Frei Galvão - Comando da Brigada Aeromóvel}
# MTEXTO: {\fArial|b1|i0|c0|p34;Adequação de Instalações}
# MTEXTO: {\fArial|b1|i0|c0|p34;Comando da Brigada Aeromóvel}
# MTEXTO: {\fArial|b1|i0|c0|p34;Eng. José  Henrique de Cássio Ruffo - CREA:5061382840-SP}
# MTEXTO: {\fArial|b1|i0|c0|p34;Local: Rua Soldado José Alves de Abreu, n° 148, 152 }
# MTEXTO: {\fArial|b1|i0|c0|p34;e 184, Jardim Rafael - Caçapava / SP}
# MTEXTO: {\fArial|b1|i0|c0|p34;Eng. Saumo Josino Cardoso Baggini Azevedo - CREA:5070429000/SP}
# MTEXTO: \pxt13;{\fArial|b1|i0|c0|p34;Responsável:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Cliente:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Empreendimento:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Data:}
# MTEXTO: {\fArial|b1|i0|c0|p34;15/07/25}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Revisão:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Rev. 0}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Escala:}
# MTEXTO: {\fArial|b1|i0|c0|p34;Indicada}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Desenho nº:}
# MTEXTO: {\fArial|b1|i0|c0|p34;4/4}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Prancha nº:}
# MTEXTO: {\fArial|b1|i0|c0|p34;5/6}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Título:}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;CH SEC PRJ INFRAESTRUTURA}
# MTEXTO: {\fArial|b1|i0|c0|p34;\C256;\c0;Eng. Resp.:}
# MTEXTO: {\fArial Black|b1|i0|c0|p34;Vila Frei Galvão - Comando da Brigada Aeromóvel}
# MTEXTO: {\fArial|b1|i0|c0|p34;Adequação de Instalações}
# MTEXTO: {\fArial|b1|i0|c0|p34;Comando da Brigada Aeromóvel}
# MTEXTO: {\fArial|b1|i0|c0|p34;Eng. José  Henrique de Cássio Ruffo - CREA:5061382840-SP}
# MTEXTO: {\fArial|b1|i0|c0|p34;Local: Rua Soldado José Alves de Abreu, n° 148, 152 }
# MTEXTO: {\fArial|b1|i0|c0|p34;e 184, Jardim Rafael - Caçapava / SP}
# MTEXTO: {\fArial|b1|i0|c0|p34;Eng. Saumo Josino Cardoso Baggini Azevedo - CREA:5070429000/SP}
# MTEXTO: {\fArial Black|b1|i0|c0|p34;Planta de Instalações Elétricas e Dados}
# MTEXTO: {\fArial Black|b1|i0|c0|p34;Planta de Instalações Elétricas e Dados}
# MTEXTO: {\fArial Black|b1|i0|c0|p34;Planta de Instalações Elétricas e Dados}
# MTEXTO: {\fArial|b1|i0|c0|p34;2/3}
# MTEXTO: {\fArial|b1|i0|c0|p34;3/3}

# %%
file.get_layers()

# %%
from collections import defaultdict

result = defaultdict(lambda: defaultdict(int))

for e in file.msp:
    layer = e.dxf.layer
    tipo = e.dxftype()
    result[layer][tipo] += 1


result
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'ARQ - Textos': defaultdict(int,
#                          {'TEXT': 14, 'MTEXT': 115, 'CIRCLE': 19, 'LINE': 22}),
#              '0': defaultdict(int,
#                          {'TEXT': 8,
#                           'HATCH': 43,
#                           'LINE': 7393,
#                           'CIRCLE': 248,
#                           'MTEXT': 486,
#                           'ARC': 62,
#                           'MULTILEADER': 16,
#                           'ACAD_TABLE': 2}),
#              'ARQ - Alvenaria Alta': defaultdict(int,
#                          {'HATCH': 47,
#                           'LINE': 4051,
#                           'ARC': 20,
#                           'LWPOLYLINE': 2}),
#              'Hidrossanitário - Esgoto': defaultdict(int, {'HATCH': 1}),
#              'Defpoints': defaultdict(int, {'HATCH': 11, 'LINE': 8}),
#              'ARQ - Cotas': defaultdict(int,
#                          {'HATCH': 113,
#                           'LINE': 478,
#                           'MULTILEADER': 47,
#                           'ELLIPSE': 8,
#                           'ARC': 16,
#                           'MTEXT': 61,
#                           'DIMENSION': 186}),
#              'IMAGEM': defaultdict(int, {'IMAGE': 1}),
#              'ARQ - Guias Calçadas Sarjetas': defaultdict(int,
#                          {'LINE': 221, 'HATCH': 2}),
#              'ARQ - Alvenaria Média-Baixa': defaultdict(int,
#                          {'LINE': 913, 'LWPOLYLINE': 39, 'HATCH': 49}),
#              'Elétrica': defaultdict(int,
#                          {'CIRCLE': 213,
#                           'LINE': 681,
#                           'MTEXT': 185,
#                           'MULTILEADER': 6,
#                           'INSERT': 2,
#                           'HATCH': 7}),
#              'LAYER 1': defaultdict(int, {'LINE': 3708, 'MTEXT': 2}),
#              'DETALHES': defaultdict(int,
#                          {'LINE': 169, 'LWPOLYLINE': 6, 'ARC': 26}),
#              'Estrutural - Fundações': defaultdict(int,
#                          {'LINE': 131, 'CIRCLE': 10}),
#              'Lógica - Dados Telefonia CFTV': defaultdict(int,
#                          {'LINE': 124, 'MTEXT': 29, 'INSERT': 2, 'CIRCLE': 4}),
#              'ARQ - Desnível': defaultdict(int, {'LINE': 90, 'HATCH': 4}),
#              'ARQ - Esquadrias': defaultdict(int, {'LINE': 451, 'ARC': 6}),
#              'Hidrossanitário - Mobiliário': defaultdict(int, {'LINE': 1}),
#              'ARQ - Escadas': defaultdict(int, {'LINE': 303, 'MTEXT': 233}),
#              'ARQ - Desnível Terreno': defaultdict(int,
#                          {'MTEXT': 131,
#                           'LINE': 431,
#                           'CIRCLE': 35,
#                           'ARC': 14,
#                           'HATCH': 21}),
#              'Hidrossanitário - Água Fria': defaultdict(int, {'MTEXT': 48}),
#              'ELE-FIXADOR GELCAM': defaultdict(int,
#                          {'LINE': 154,
#                           'LWPOLYLINE': 816,
#                           'DIMENSION': 32,
#                           'MTEXT': 4,
#                           'CIRCLE': 6,
#                           'HATCH': 2}),
#              'ARQ - Grades': defaultdict(int, {'LWPOLYLINE': 22, 'LINE': 56}),
#              'ELE-BARRA CHATA ALUMÍNIO': defaultdict(int,
#                          {'LWPOLYLINE': 232,
#                           'CIRCLE': 12,
#                           'TEXT': 12,
#                           'LINE': 1018,
#                           'HATCH': 16,
#                           'ARC': 1018}),
#              'ELE-CX. INSPEÇÃO': defaultdict(int,
#                          {'CIRCLE': 10,
#                           'LWPOLYLINE': 14,
#                           'LINE': 126,
#                           'HATCH': 6,
#                           'ARC': 10,
#                           'ELLIPSE': 22,
#                           'SPLINE': 6}),
#              'ELE-HASTE COBREADA': defaultdict(int,
#                          {'LINE': 370,
#                           'ELLIPSE': 40,
#                           'ARC': 20,
#                           'LWPOLYLINE': 2}),
#              'ELE-CONECTOR SPLIT BOLT': defaultdict(int,
#                          {'LWPOLYLINE': 20, 'LINE': 156, 'ARC': 12}),
#              'ELE-CONECTOR DE EMENDA': defaultdict(int,
#                          {'LINE': 80, 'CIRCLE': 40}),
#              'ELE-TERMINAL AÉREO': defaultdict(int, {'LWPOLYLINE': 34}),
#              'ELE-REBITE': defaultdict(int, {'LWPOLYLINE': 20}),
#              'ELE-FIAÇÃO1': defaultdict(int,
#                          {'LINE': 228, 'LWPOLYLINE': 12, 'LEADER': 10}),
#              'ELE-TEXTOS': defaultdict(int, {'TEXT': 302}),
#              'ELE-TEXTO5': defaultdict(int, {'TEXT': 4}),
#              'ELE-MALHA SPDA': defaultdict(int,
#                          {'LINE': 122, 'ARC': 30, 'LWPOLYLINE': 50}),
#              'ELE-FIAÇÃO': defaultdict(int, {'TEXT': 34}),
#              'ELE-CORDOALHA': defaultdict(int, {'LWPOLYLINE': 2}),
#              'ELE-LINHA FINA': defaultdict(int,
#                          {'HATCH': 4,
#                           'LINE': 1044,
#                           'ELLIPSE': 66,
#                           'ARC': 24,
#                           'LWPOLYLINE': 340,
#                           'POLYLINE': 12}),
#              'ELE-MALHA TERRA': defaultdict(int,
#                          {'ARC': 118,
#                           'LINE': 252,
#                           'ELLIPSE': 12,
#                           'LWPOLYLINE': 76,
#                           'CIRCLE': 24}),
#              'ELE-TUBO DESCIDA': defaultdict(int, {'LINE': 134}),
#              'ELE-SOLDA EXOTÉRMICA': defaultdict(int,
#                          {'LINE': 148,
#                           'ELLIPSE': 26,
#                           'ARC': 42,
#                           'LWPOLYLINE': 18,
#                           'SPLINE': 8}),
#              'ELE-TERMINAL COMPRESSÃO': defaultdict(int,
#                          {'LINE': 24, 'ELLIPSE': 6, 'ARC': 6}),
#              'EST-VIGAS COBERTURA EXISTENTE': defaultdict(int, {'LINE': 44}),
#              'ELE-CONCETOR BIMETÁLICO': defaultdict(int,
#                          {'LINE': 66, 'ARC': 16}),
#              'Símbolos - Indicação Fachada Elevação Vista': defaultdict(int,
#                          {'HATCH': 15, 'LINE': 74, 'MTEXT': 11, 'CIRCLE': 6}),
#              'ARQ - Projeções': defaultdict(int, {'LINE': 154, 'MTEXT': 45}),
#              'Estrutural - Pilares': defaultdict(int, {'LINE': 8}),
#              'CANTEIRO': defaultdict(int, {'INSERT': 1}),
#              'Estrutural - Lajes': defaultdict(int, {'LINE': 28}),
#              '035': defaultdict(int, {'MTEXT': 35}),
#              'Estrutural - Vigas': defaultdict(int, {'LINE': 8}),
#              'Arquitetônico - Textos': defaultdict(int,
#                          {'LINE': 69, 'ARC': 16, 'CIRCLE': 16, 'MTEXT': 27}),
#              'Arquitetônico - Alvenaria Alta': defaultdict(int,
#                          {'LINE': 43, 'ARC': 16}),
#              'Hidrossanitário - Água Pluvial': defaultdict(int,
#                          {'LINE': 132,
#                           'CIRCLE': 5,
#                           'SPLINE': 14,
#                           'INSERT': 2,
#                           'MTEXT': 2}),
#              'Símbolos - Quadro de Acabamentos': defaultdict(int,
#                          {'LINE': 65,
#                           'MTEXT': 79,
#                           'CIRCLE': 10,
#                           'LWPOLYLINE': 2,
#                           'HATCH': 7}),
#              'ARQ - Cobertura': defaultdict(int, {'LINE': 18}),
#              'arvore': defaultdict(int, {'CIRCLE': 5}),
#              'ELE-CIRCUITO': defaultdict(int,
#                          {'MTEXT': 7,
#                           'LINE': 1897,
#                           'INSERT': 46,
#                           'TEXT': 590,
#                           'LWPOLYLINE': 117,
#                           'CIRCLE': 447,
#                           'ARC': 91})})

# %%
import math
def calcula():
    soma = 0
    file.msp.query('LINE[layer=="ELE-FIOS"]')
    for e in file.msp:
        if e.dxftype() == 'LINE':
            start = e.dxf.start
            end = e.dxf.end
            comprimento = math.dist((start.x, start.y), (end.x, end.y))
            soma += comprimento

# %%
for e in file.msp:
    if e.dxf.layer == 'ELE-FIAÇÃO':
        print(e)

# file.get_layers()

# %%
for e in file.msp.query('LINE[layer=="ELE-FIAÇÃO"]'):
    print(e)

# %%
for e in file.msp:
    if e.dxf.layer == 'ELE-FIAÇÃO' and e.dxftype() == 'TEXT':
        print(e.dxf.text, e.dxf.insert)

# %%
for e in file.msp:
    if e.dxftype() == 'INSERT':
        print(e.dxf.name, e.dxf.layer)

# %%
for e in file.msp.query('INSERT'):
    for att in e.attribs:
        print(att.dxf.tag, att.dxf.text)
